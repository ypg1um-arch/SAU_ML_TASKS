# %% [markdown]
# <a href="https://colab.research.google.com/github/ypg1um-arch/SAU_ML_TASKS/blob/main/MAGNET_BRCA_Hyperparam_Tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --default-timeout=1000 -q torch-geometric==2.4.0

# !pip install -q lightning==2.1.3 pandas==2.1.1 matplotlib==3.10.0


# !pip install -q umap-learn==0.5.7 yacs comet_ml "ray[tune]"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 46.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 118.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 69.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 61.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install "numpy<2.0.0"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 93.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.1 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# mizani 0.13.5 requires pandas>=2.2.0, but you have pandas 2.1.1 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pointpats 2.5.5 requires pandas>=2.2, but you have pandas 2.1.1 which is incompatible.
# ...

# %%
#!git clone https://github.com/SinaTabakhi/MAGNET

# %cd MAGNET

# 3. List files to confirm you are in the right spot
# !ls
# Out:
# /content/MAGNET
# configs  dataloader  main_data_split.py  main_tune.py  preprocess  trainer
# data	 image	     main_inference.py	 model	       README.md   utils.py

# %%
# !python main_tune.py --cfg configs/MAGNET_BRCA.yaml
# Out:
# Trial status: 4 TERMINATED | 1 RUNNING | 200 PENDING
# Current time: 2026-06-25 18:16:22. Total running time: 53min 37s
# Logical resource usage: 0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status         sparsity_rate     dropout_rate            lr     hid_dims     att_num_heads     gnn_num_layers     iter     total time (s)     accuracy │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ hypertune_magnet_7a6e5_00004   RUNNING                 0.55              0.2   0.000490559          256                 4                  2                                          │
# ...

# %%
#Trial 00002 is the overall winner so far with 91.25% accuracy.
#It benefits from a higher number of attention heads (8) and a modest dropout rate (0.1).
#Trial 00003 and 00004 are right behind it (~91.0% - 91.4%).
#Both of these configurations use a larger hidden dimension layer (hid_dims=256), which gives the network more capacity to learn complex graph patterns.
#Trial 00001 collapsed to 46.66% accuracy.
#The learning rate was set way too low (1.11822e-05).
#The model did not have enough optimization speed to escape random initialization weights within its single iteration.
# Params for high accuracy:-
#sparsity_rate: 0.70 to 0.85 (higher sparsity means lower gpu consumption)[try to lower is feasible]
#dropout_rate: 0.1 to 0.2 (dropout rates in this range are working weel for the data)
#lr: 0.0005 (not too high, not too low)
#hid_dims: 256 (reasonable)
#att_num_heads: 4 or 8 (use lower number of att heads if hidden dimensions are more[like 256])
# 2 gnn layers are good enough
#Note that this only performs 1 iteration on 5 configs, for better params range run it for more configs
